# %%
import pandas as pd

# %%
data = pd.read_csv('/home/tien/my_project/botchat/test_model/decision_making_test.csv')
data['Trả lời'] = data['Trả lời'].replace({'Không tiến hành': 'N', 'Tiến hành': 'Y'})
situation = data['Câu hỏi']
result = data['Trả lời']

# %%
data
# Out:
#                                               Câu hỏi Trả lời
# 0   Bệnh nhân bị bóc tách động mạch chủ cấp Type A...       N
# 1   Bệnh nhân có phình động mạch chủ gốc/lên không...       Y
# 2   Bệnh nhân mắc hội chứng Loeys-Dietz do biến th...       Y
# 3   Bệnh nhân mắc hội chứng Turner (≥15 tuổi) nên ...       N
# 4   Nên sử dụng thang Z-score để báo cáo mức độ gi...       N
# 5   Bệnh nhân bị huyết khối thành trong (IMH) Type...       Y
# 6   Bệnh nhân bị phình động mạch chủ bụng (AAA) có...       Y
# 7   Bệnh nhân phình động mạch chủ ngực-bụng (TAAA)...       Y
# 8   Bệnh nhân bị bóc tách động mạch chủ Type B khô...       N
# 9   Có nên tiến hành PCI cho bệnh nhân có tắc nghẽ...       N
# 10  Bệnh nhân có bệnh thân chung động mạch vành (L...       N
# 11  Bệnh nhân cần tái thông mạch vành trước phẫu t...       N
# 12  Bệnh nhân có tổn thương mạch vành vôi hóa nặng...       Y
# 13  Nên sử dụng stent kim loại trần (BMS) thay vì ...       Y
# 14  Trong CABG "nên ưu tiên sử dụng động mạch quay...       Y
# 15  Bệnh nhân đang dùng Aspirin trước CABG có nên ...       Y
# 16  Bệnh nhân bị bóc tách động mạch vành tự phát (...       N
# 17  Bệnh nhân trải qua PCI ghép tĩnh mạch hiển (SV...       Y
# 18  Bệnh nhân có van tim cơ học và rung nhĩ (AF) c...       N
# 19  Bệnh nhân có hẹp van động mạch chủ (AS) nặng "...       Y
# 20  Bệnh nhân có BAV "không có yếu tố rủi ro bổ su...       Y
# 21  Bệnh nhân bị van tim sinh học có huyết khối lầ...       Y
# 22  Bệnh nhân bị hẹp van hai lá (MS) do thấp tim "...       N
# 23  Bệnh nhân bị Hở van hai lá (MR) thứ phát nặng ...       Y
# 24  Bệnh nhân có van cơ học cần tạm ngừng VKA để p...       Y
# 25  Bệnh nhân đang dùng VKA có INR từ 4.5 đến 10.0...       N
# 26  Bệnh nhân cần thay van tim "tuổi dưới 50 có nê...       Y
# 27  Bệnh nhân bị hở van hai lá (MR) nguyên phát nặ...       Y
# 28  Bệnh nhân có huyết khối van sinh học lần đầu v...       Y
# 29  Có nên thực hiện TAVI cho bệnh nhân hẹp van độ...       Y
# 30  Có nên tiếp tục sử dụng ACE inhibitors hoặc AR...       N
# 31  Phụ nữ có van cơ học cần Warfarin >5 mg/ngày đ...       Y
# 32  Phụ nữ mang thai có van cơ học "không thể theo...       N
# 33  Bệnh nhân mắc bệnh động mạch chủ di truyền (HT...       Y
# 34  Bệnh nhân bị hở van hai lá (MR) thứ phát do th...       Y
# 35  Bệnh nhân mắc phình động mạch chủ (TAA) có nên...       Y
# 36  Bệnh nhân mắc bệnh van động mạch chủ hai mảnh ...       N
# 37  Bệnh nhân bị hẹp van hai lá (MS) do vôi hóa (C...       N
# 38  Bệnh nhân cần AVR nhưng có vôi hóa động mạch c...       Y
# 39  Phẫu thuật thay van động mạch chủ (SAVR) nên đ...       N
# 40  Bệnh nhân bị phình động mạch chủ gốc hoặc động...       Y
# 41  Trong trường hợp bóc tách động mạch chủ Type B...       Y
# 42  Nếu bệnh nhân có Kommerell’s Diverticulum mà đ...       Y
# 43  Khi quyết định can thiệp động mạch chủ "có nên...       Y
# 44  Bệnh nhân mắc bệnh thân chung động mạch vành (...       Y
# 45  Bệnh nhân có BAV có nên được sàng lọc bằng TTE...       Y
# 46  Bệnh nhân có van cơ học đang mang thai nên sử ...       N
# 47  Bệnh nhân bị tắc nghẽn mãn tính toàn bộ (CTO) ...       N
# 48  Bệnh nhân có nguy cơ cao (ví dụ: suy thận giai...       N
# 49  Bệnh nhân cần phẫu thuật van động mạch chủ "nế...       Y
# 50  Bệnh nhân bị phình động mạch chủ được biết là ...       Y
# 51  Bệnh nhân bị đau thắt ngực ổn định (SIHD) có n...       Y
# 52  Trong quá trình phát triển hướng dẫn lâm sàng ...       Y

# %%
print(result.value_counts())
# Out:
# Trả lời
# Y    34
# N    19
# Name: count, dtype: int64
